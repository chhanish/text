# %% [markdown]
# <a href="https://colab.research.google.com/github/chhanish/text/blob/main/m13_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 13: Texts

# %% [markdown]
# We'll use `spaCy` and `wordcloud` to play with text data. `spaCy` is probably the best python package for analyzing text data. It's capable and super fast. Let's install them.
#
#     pip install wordcloud spacy
#
# To use spaCy, you also need to download models. Run:
#
#     python -m spacy download en
#
#
# ## SpaCy basics

# %%
pip install wordcloud spacy
# Out:
# Requirement already satisfied: wordcloud in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (1.8.2.2)
# Requirement already satisfied: spacy in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.59.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.1.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.10.2)
# Requirement already satisfied: jinja2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.3)
# Requirement already satisfied: setuptools in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.6.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.20.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: matplotlib in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from wordcloud) (3.3.4)
# Requirement already satisfied: pillow in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from wordcloud) (8.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: six in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.1.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.20.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.3)
# Requirement already satisfied: packaging>=20.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.59.0)
# Requirement already satisfied: setuptools in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: pathy>=0.3.5 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.6.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: jinja2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hanishchidipothu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)

# %%
import spacy
import wordcloud

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Usually the first step of text analysis is _tokenization_, which is the process of breaking a document into "tokens". You can roughly think of it as extracting each word.

# %%
doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')

for token in doc:
    print(token)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion

# %% [markdown]
# As you can see, it's not exactly same as `doc.split()`. You'd want to have `$` as a separate token because it has a particular meaning (USD). Actually, as shown in an example (https://spacy.io/usage/spacy-101#annotations-pos-deps), `spaCy` figures out a lot of things about these tokens. For instance,

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_)
# Out:
# Apple Apple PROPN NNP
# is be AUX VBZ
# looking look VERB VBG
# at at ADP IN
# buying buy VERB VBG
# U.K. U.K. PROPN NNP
# startup startup NOUN NN
# for for ADP IN
# $ $ SYM $
# 1 1 NUM CD
# billion billion NUM CD

# %% [markdown]
# It figured it out that `Apple` is a proper noun ("PROPN" and "NNP"; see [here](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) for the part of speech tags).
#
# `spaCy` has a visualizer too.

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="72e60366b19d4a61b6581f9f35926c59-0" class="displacy" width="1150" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">buying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">startup</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">billion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-0" stroke-width="2px" d="M70,152.0 C70,52.0 245.0,52.0 245.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,154.0 L162,142.0 178,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-2" stroke-width="2px" d="M270,152.0 C270,102.0 340.0,102.0 340.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340.0,154.0 L348.0,142.0 332.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-3" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M440.0,154.0 L448.0,142.0 432.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-4" stroke-width="2px" d="M470,152.0 C470,102.0 540.0,102.0 540.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M540.0,154.0 L548.0,142.0 532.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-5" stroke-width="2px" d="M470,152.0 C470,52.0 645.0,52.0 645.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,154.0 L653.0,142.0 637.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-6" stroke-width="2px" d="M670,152.0 C670,102.0 740.0,102.0 740.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,154.0 L748.0,142.0 732.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-7" stroke-width="2px" d="M870,152.0 C870,52.0 1045.0,52.0 1045.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-72e60366b19d4a61b6581f9f35926c59-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,154.0 L862,142.0 878,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-72e60366b19d4a61b6581f9f35926c59-0-8" stroke-width="2px" d="M970,152.0 C970,102.0 1040.0,102.0 1040.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink

# %% [markdown]
# It even recognizes entities and can visualize them.

# %%
text = """But Google is starting from behind. The company made a late push
into hardware, and Apple’s Siri, available on iPhones, and Amazon’s Alexa
software, which runs on its Echo and Dot devices, have clear leads in
consumer adoption."""

doc2 = nlp(text)
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">But
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is starting from behind. The company made a late push</br>into hardware, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple’s Siri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , available on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s Alexa</br>software, which runs on its
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  devices, have clear leads in</br>consumer adoption.</div></span>

# %% [markdown]
# ## Let's read a book
#
# Shall we load some serious book? You can use any books that you can find as a text file.

# %%
import requests

metamorphosis_book = requests.get('http://www.gutenberg.org/cache/epub/5200/pg5200.txt').content

# %%
metamorphosis_book[:1000]
# Out:
# b'\xef\xbb\xbfThe Project Gutenberg EBook of Metamorphosis, by Franz Kafka\r\nTranslated by David Wyllie.\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.  You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n** This is a COPYRIGHTED Project Gutenberg eBook, Details Below **\r\n**     Please follow the copyright guidelines in this file.     **\r\n\r\n\r\nTitle: Metamorphosis\r\n\r\nAuthor: Franz Kafka\r\n\r\nTranslator: David Wyllie\r\n\r\nRelease Date: August 16, 2005 [EBook #5200]\r\nFirst posted: May 13, 2002\r\nLast updated: May 20, 2012\r\n\r\nLanguage: English\r\n\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK METAMORPHOSIS ***\r\n\r\n\r\n\r\n\r\nCopyright (C) 2002 David Wyllie.\r\n\r\n\r\n\r\n\r\n\r\n  Metamorphosis\r\n  Franz Kafka\r\n\r\nTranslated by David Wyllie\r\n\r\n\r\n\r\nI\r\n\r\n\r\nOne morning, when Gregor Samsa woke from troubled dreams, he found\r\nhimself transformed in his bed into a horrible vermi'

# %% [markdown]
# Looks like we have successfully loaded the book. You'd probably want to remove the parts at the beginning and at the end that are not parts of the book if you are doing a serious analysis, but let's ignore them for now. Let's try to feed this directly into `spaCy`.

# %%
# Try to run this cell. Is it giving exception? Why doesn't it work? Think about it for a moment before moving on!
try:
    doc_metamor = nlp(metamorphosis_book)
except TypeError as e:
    print("metamorphosis_book is not converted to string:", str(e))
# Out:
# ---------------------------------------------------------------------------
# ExtraData                                 Traceback (most recent call last)
# <ipython-input-10-40e78462a2a5> in <module>
#       1 # Try to run this cell. Is it giving exception? Why doesn't it work? Think about it for a moment before moving on!
#       2 try:
# ----> 3     doc_metamor = nlp(metamorphosis_book)
#       4 except TypeError as e:
#       5     print("metamorphosis_book is not converted to string:", str(e))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1012         DOCS: https://spacy.io/api/language#call
#    1013         """
# -> 1014         doc = self._ensure_doc(text)
#    1015         if component_cfg is None:
#    1016             component_cfg = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1105             return self.make_doc(doc_like)
#    1106         if isinstance(doc_like, bytes):
# -> 1107             return Doc(self.vocab).from_bytes(doc_like)
#    1108         raise ValueError(Errors.E1041.format(type=type(doc_like)))
#    1109
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.Doc.from_bytes()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/srsly/_msgpack_api.py in msgpack_loads(data, use_list)
#      25     # msgpack-python docs suggest disabling gc before unpacking large messages
#      26     gc.disable()
# ---> 27     msg = msgpack.loads(data, raw=False, use_list=use_list)
#      28     gc.enable()
#      29     return msg
#
# ~/opt/anaconda3/lib/python3.8/site-packages/srsly/msgpack/__init__.py in unpackb(packed, **kwargs)
#      77             object_hook = functools.partial(decoder, chain=object_hook)
#      78         kwargs["object_hook"] = object_hook
# ---> 79     return _unpackb(packed, **kwargs)
#      80
#      81
#
# ~/opt/anaconda3/lib/python3.8/site-packages/srsly/msgpack/_unpacker.pyx in srsly.msgpack._unpacker.unpackb()
#
# ExtraData: unpack(b) received extra data.

# %% [markdown]
# ## On encodings
#
# What are we getting this error? What does it mean? It says `nlp` function expects `str` type but we passed `bytes`.

# %%
type(metamorphosis_book)
# Out:
# bytes

# %% [markdown]
# Indeed, the type of `metamorphosis_book` is `bytes`. But as we have seen above, we can see the book contents right? What's going on?
#
# Well, the problem is that a byte sequence is not yet a proper string until we know how to decode it. A string is an abstract object and we need to specify an encoding to write the string into a file. For instance, if I have a string of Korean characters like "안녕", there are several encodings that I can specify to write that into a file, and depending on the encoding that I choose, the byte sequences can be totally different from each other. This is a really important (and confusing) topic, but because it's beyond the scope of the course, I'll just link a nice post about encoding: http://kunststube.net/encoding/

# %%
"안녕".encode('utf8')
# Out:
# b'\xec\x95\x88\xeb\x85\x95'

# %%
# b'\xec\x95\x88\xeb\x85\x95'.decode('euc-kr') <- what happen if you do this?
b'\xec\x95\x88\xeb\x85\x95'.decode('utf8')
# Out:
# '안녕'

# %%
"안녕".encode('euc-kr')
# Out:
# b'\xbe\xc8\xb3\xe7'

# %%
b'\xbe\xc8\xb3\xe7'.decode('euc-kr')
# Out:
# '안녕'

# %% [markdown]
# You can decode with "wrong" encoding too.

# %%
b'\xbe\xc8\xb3\xe7'.decode('latin-1')
# Out:
# '¾È³ç'

# %% [markdown]
# As you can see the same string can be encoded into different byte sequences depending on the encoding. It's a really ~~annoying~~ fun topic and if you need to deal with text data, you must have a good understanding of it.
#
# I know that Project Gutenberg uses `utf-8` encoding. So let's decode the byte sequence into a string.

# %%
# TODO: Convert the bytes into string and replace below dummy value with your code.
metamorphosis_book_str = 'DUMMY PLACEHOLDER'
metamorphosis_book_str = metamorphosis_book.decode('utf8')

# %%
type(metamorphosis_book_str)
# Out:
# str

# %% [markdown]
# Shall we try again?

# %%
doc_metamor = nlp(metamorphosis_book_str)

# %%
words = [token.text for token in doc_metamor
         if token.is_stop != True and token.is_punct != True]

# %% [markdown]
# ## Let's count!

# %%
from collections import Counter

Counter(words).most_common(5)
# Out:
# [('\r\n', 1970), (' ', 670), ('Gregor', 298), ('\r\n\r\n', 148), ('room', 131)]

# %% [markdown]
# a lot of newline characters and multiple spaces. A quick and dirty way to remove them is split & join. The idea is that you split the document using `split()` and then join with a single space ` `. Can you implement it and print the 10 most common words?

# %%
# Implement
document=' '.join(metamorphosis_book_str.split()),nlp(document)
words=[token.text for token in doc_new
         if token.is_stop != True and token.is_punct != True]
Counter(words).most_common(10)
# Out:
# [('Gregor', 298),
#  ('room', 131),
#  ('sister', 101),
#  ('father', 99),
#  ('door', 87),
#  ('mother', 85),
#  ('Project', 84),
#  ('Gutenberg', 84),
#  ('work', 74),
#  ('way', 64)]

# %% [markdown]
# Let's keep the object with word count.

# %%
word_cnt = Counter(words)

# %% [markdown]
# ## Some wordclouds?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Can you check out the `wordcloud` package documentation and create a word cloud from the word count object that we created from the book above and plot it?

# %%
# Implement: create a word cloud object
from wordcloud import WordCloud
cloud=WordCloud(width = 800, height = 800,
                background_color ='red').generate_from_frequencies(word_cnt)
plt.figure(figsize=(15,20))
plt.imshow(cloud)

# %%
[token.pos_ for token in doc_new]
# Out:
# ['PRON',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'ADP',
#  'PROPN',
#  'PUNCT',
#  'ADP',
#  'PROPN',
#  'PROPN',
#  'VERB',
#  'ADP',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'DET',
#  'PROPN',
#  'AUX',
#  'ADP',
#  'DET',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'ADV',
#  'ADP',
#  'DET',
#  'NOUN',
#  'CCONJ',
#  'ADP',
#  'ADV',
#  'PRON',
#  'NOUN',
#  'ADV',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PRON',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'ADV',
#  'CCONJ',
#  'VERB',
#  'VERB',
#  'VERB',
#  'PRON',
#  'ADP',
#  'DET',
#  'NOUN',
#  'ADP',
#  'DET',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'VERB',
#  'ADP',
#  'DET',
#  'PROPN',
#  'CCONJ',
#  'ADV',
#  'ADP',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'DET',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'PROPN',
#  'ADP',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'INTJ',
#  'VERB',
#  'DET',
#  'NOUN',
#  'NOUN',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'NUM',
#  'PUNCT',
#  'NUM',
#  'X',
#  'PROPN',
#  'SYM',
#  'NUM',
#  'PUNCT',
#  'ADV',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NUM',
#  'PUNCT',
#  'NUM',
#  'ADJ',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NUM',
#  'PUNCT',
#  'NUM',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PROPN',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'NUM',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'VERB',
#  'ADP',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'NUM',
#  'NOUN',
#  'PUNCT',
#  'SCONJ',
#  'PROPN',
#  'PROPN',
#  'VERB',
#  'ADP',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PRON',
#  'VERB',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'ADP',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'DET',
#  'ADJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'ADV',
#  'ADJ',
#  'CCONJ',
#  'VERB',
#  'ADP',
#  'NOUN',
#  'ADP',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'DET',
#  'NOUN',
#  'AUX',
#  'ADV',
#  'ADJ',
#  'PART',
#  'VERB',
#  'PRON',
#  'CCONJ',
#  'VERB',
#  'ADJ',
#  'PART',
#  'VERB',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'ADV',
#  'ADJ',
#  'VERB',
#  'ADP',
#  'DET',
#  'NOUN',
#  'ADP',
#  'DET',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'PUNCT',
#  'VERB',
#  'ADV',
#  'ADV',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'VERB',
#  'ADP',
#  'PRON',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'PART',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'DET',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'SCONJ',
#  'DET',
#  'ADJ',
#  'ADV',
#  'ADJ',
#  'PUNCT',
#  'VERB',
#  'ADV',
#  'ADP',
#  'PRON',
#  'NUM',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'DET',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'ADP',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'AUX',
#  'DET',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'ADP',
#  'PRON',
#  'ADV',
#  'VERB',
#  'DET',
#  'NOUN',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'ADV',
#  'VERB',
#  'ADP',
#  'ADP',
#  'DET',
#  'VERB',
#  'NOUN',
#  'CCONJ',
#  'VERB',
#  'ADP',
#  'DET',
#  'ADJ',
#  'PUNCT',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'DET',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'ADP',
#  'DET',
#  'NOUN',
#  'NOUN',
#  'CCONJ',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'ADV',
#  'PUNCT',
#  'VERB',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'DET',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'ADV',
#  'VERB',
#  'PART',
#  'VERB',
#  'ADP',
#  'DET',
#  'NOUN',
#  'ADP',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'AUX',
#  'AUX',
#  'VERB',
#  'VERB',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PRON',
#  'VERB',
#  'ADV',
#  'ADJ',
#  'PUNCT',
#  'PUNCT',
#  'SCONJ',
#  'ADP',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'ADV',
#  'CCONJ',
#  'VERB',
#  'DET',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'CCONJ',
#  'PRON',
#  'AUX',
#  'PRON',
#  'PRON',
#  'AUX',
#  'ADJ',
#  'PART',
#  'VERB',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'ADP',
#  'VERB',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'ADP',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'AUX',
#  'PART',
#  'VERB',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'ADV',
#  'ADV',
#  'PRON',
#  'VERB',
#  'PRON',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'ADV',
#  'VERB',
#  'ADV',
#  'ADP',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'AUX',
#  'VERB',
#  'PRON',
#  'DET',
#  'NUM',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'SCONJ',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'PART',
#  'VERB',
#  'PART',
#  'VERB',
#  'ADP',
#  'DET',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'ADV',
#  'VERB',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'PART',
#  'VERB',
#  'DET',
#  'ADJ',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'ADV',
#  'PRON',
#  'PRON',
#  'AUX',
#  'ADV',
#  'VERB',
#  'ADV',
#  'PUNCT',
#  'PUNCT',
#  'INTJ',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'AUX',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'NOUN',
#  'ADV',
#  'CCONJ',
#  'NOUN',
#  'ADP',
#  'PUNCT',
#  'VERB',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'VERB',
#  'ADV',
#  'ADJ',
#  'NOUN',
#  'ADP',
#  'VERB',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'ADP',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'PRON',
#  'VERB',
#  'DET',
#  'NOUN',
#  'ADP',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'ADP',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'ADJ',
#  'CCONJ',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'ADP',
#  'ADJ',
#  'NOUN',
#  'DET',
#  'DET',
#  'NOUN',
#  'SCONJ',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'ADV',
#  'VERB',
#  'PART',
#  'VERB',
#  'PRON',
#  'CCONJ',
#  'VERB',
#  'ADJ',
#  'ADP',
#  'PRON',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'PRON',
#  'VERB',
#  'ADP',
#  'PROPN',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'ADP',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'ADV',
#  'ADV',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'ADP',
#  'DET',
#  'NOUN',
#  'SCONJ',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'ADV',
#  'PUNCT',
#  'VERB',
#  'SCONJ',
#  'DET',
#  'NOUN',
#  'AUX',
#  'PUNCT',
#  'CCONJ',
#  'VERB',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'ADP',
#  'NOUN',
#  'ADP',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'PRON',
#  'AUX',
#  'PART',
#  'VERB',
#  'PRON',
#  'PART',
#  'VERB',
#  'ADP',
#  'PUNCT',
#  'CCONJ',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'PART',
#  'VERB',
#  'DET',
#  'NOUN',
#  'ADP',
#  'NUM',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'PRON',
#  'ADV',
#  'ADV',
#  'SCONJ',
#  'ADV',
#  'ADV',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'PRON',
#  'PRON',
#  'AUX',
#  'VERB',
#  'ADP',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'ADV',
#  'ADP',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'ADP',
#  'ADV',
#  'DET',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PRON',
#  'ADJ',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PART',
#  'VERB',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'ADJ',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'DET',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'PUNCT',
#  'ADP',
#  'NOUN',
#  'PUNCT',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'ADV',
#  'ADP',
#  'DET',
#  'NOUN',
#  'NOUN',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PART',
#  'VERB',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'DET',
#  'NOUN',
#  'AUX',
#  'ADV',
#  'ADV',
#  'VERB',
#  'ADV',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'PART',
#  'ADV',
#  'VERB',
#  'PRON',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'AUX',
#  'VERB',
#  'ADP',
#  'ADP',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'ADV',
#  'PRON',
#  'AUX',
#  'AUX',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'PUNCT',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'PART',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'PART',
#  'VERB',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'AUX',
#  'VERB',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'ADV',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'AUX',
#  'VERB',
#  'ADP',
#  'ADP',
#  'DET',
#  'NOUN',
#  'CCONJ',
#  'VERB',
#  'PRON',
#  'ADV',
#  'PRON',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'PRON',
#  'PRON',
#  'AUX',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'VERB',
#  'ADV',
#  'PRON',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'VERB',
#  'ADV',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'CCONJ',
#  'PRON',
#  'AUX',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'PART',
#  'AUX',
#  'VERB',
#  'ADV',
#  'ADV',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'ADP',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'ADP',
#  'ADV',
#  'ADV',
#  'PUNCT',
#  'ADV',
#  'SCONJ',
#  'PRON',
#  'VERB',
#  'PART',
#  'VERB',
#  'ADV',
#  'ADV',
#  'ADV',
#  'SCONJ',
#  'DET',
#  'NOUN',
#  'AUX',
#  'ADJ',
#  'ADP',
#  'VERB',
#  'PUNCT',
#  'INTJ',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'ADV',
#  'DET',
#  'NOUN',
#  'PUNCT',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'DET',
#  'NOUN',
#  'ADV',
#  'PART',
#  'VERB',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'PART',
#  'NOUN',
#  'ADP',
#  'PRON',
#  'PUNCT',
#  'DET',
#  'NUM',
#  'CCONJ',
#  'NUM',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'ADV',
#  'PRON',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'SCONJ',
#  'PRON',
#  'AUX',
#  'VERB',
#  'DET',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'ADV',
#  'ADP',
#  'PRON',
#  'ADV',
#  'PUNCT',
#  'PRON',
#  'AUX',
#  'VERB',
#  'PART',
#  'VERB',
#  'ADP',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'NUM',
#  'PUNCT',
#  'PUNCT',
#  'CCONJ',
#  'PRON',
#  'VERB',
#  'ADP',
#  'ADP',
#  'DET',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'ADP',
#  'DET',
#  'NOUN',
#  'ADP',
#  'NOUN',
#  'PUNCT',
#  ...]

# %% [markdown]
# **Q: Can you create a word cloud for a certain part of speech, such as nouns, verbs, proper nouns, etc. (pick one)?**

# %%
# Implement
noun_words=[token.text for token in doc_new if token.pos_=='ADP']
noun_cnt=Counter(noun_words)
cloud3=WordCloud(width = 800, height = 800,
                background_color ='white').generate_from_frequencies(noun_cnt)

plt.figure(figsize=(15,20))
plt.imshow(cloud3)
